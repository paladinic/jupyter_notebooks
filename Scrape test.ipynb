# %%
import requests
import urllib.request
import time
import pandas as pd
from bs4 import BeautifulSoup

# %%
s = "https://en.wikipedia.org/wiki/Lists_of_films"

# %%
def scrape(url,element="",arg="",skip_no_arg=True):
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"html.parser")
    if (element == "") | (element == None):
        elements = soup.find_all("p")
    else:
        elements = soup.find_all(element)
    element_tables = []
    for e in elements:
        if (arg != "") & (arg != None):
            try:
                e = e[arg]
                element_tables.append(str(e))
            except KeyError:
                print("arg not found in element")
                if not(skip_no_arg):
                    element_tables.append(str(e))
        else:
            element_tables.append(str(e))
    return element_tables

# %%
l = scrape(url=s,element="table",arg="href",skip_no_arg=False)
# Out:
# arg not found in element
# arg not found in element
# arg not found in element
# arg not found in element
# arg not found in element

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# ['<table align="center">\n<tbody><tr>\n<td>\n<table class="wikitable" style="text-align:center">\n<tbody><tr>\n<th colspan="7">Alphabetically indexed lists of films\n</th></tr>\n<tr>\n<td style="width:46px"><a href="/wiki/List_of_films:_numbers" title="List of films: numbers">\xa00-9\xa0</a></td>\n<td style="width:46px"><a href="/wiki/List_of_films:_A" title="List of films: A">\xa0A\xa0</a></td>\n<td style="width:46px"><a href="/wiki/List_of_films:_B" title="List of films: B">\xa0B\xa0</a></td>\n<td style="width:46px"><a href="/wiki/List_of_films:_C" title="List of films: C">\xa0C\xa0</a></td>\n<td style="width:46px"><a href="/wiki/List_of_films:_D" title="List of films: D">\xa0D\xa0</a></td>\n<td style="width:46px"><a href="/wiki/List_of_films:_E" title="List of films: E">\xa0E\xa0</a></td>\n<td style="width:46px"><a href="/wiki/List_of_films:_F" title="List of films: F">\xa0F\xa0</a>\n</td></tr>\n<tr>\n<td><a href="/wiki/List_of_films:_G" title="List of films: G">\xa0G\xa0</a></td>
# ...

# %%
url = s
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page,"html.parser")

# %%
print([i for i in soup.children])
# Out:
# ['html', '\n', <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Lists of films - Wikipedia</title>
# ...

# %%
[tag.name for tag in soup.find_all()]
# Out:
# ['html',
#  'head',
#  'meta',
#  'title',
#  'script',
#  'script',
#  'link',
#  'script',
#  'meta',
#  'link',
#  'meta',
#  'meta',
#  'meta',
#  'meta',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'link',
#  'body',
#  'div',
#  'div',
#  'div',
#  'a',
#  'div',
#  'div',
#  'h1',
#  'div',
#  'div',
#  'div',
#  'div',
#  'div',
#  'a',
#  'a',
#  'div',
#  'div',
#  'div',
#  'p',
#  'b',
#  'div',
#  'input',
#  'div',
#  'h2',
#  'span',
#  'label',
#  'ul',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
#  'a',
#  'span',
#  'span',
#  'li',
# ...

# %%
scrape(s,"a","href")
# Out:
# arg not found in element
# ['#mw-head',
#  '#searchInput',
#  '#Alphabetical_indices',
#  '#By_year',
#  '#By_era',
#  '#By_award',
#  '#By_critical_or_popular_judgment',
#  '#By_country_of_origin',
#  '#By_production_company',
#  '#By_budget',
#  '#By_revenue',
#  '#By_setting',
#  '#By_shooting_location',
#  '#By_genre',
#  '#Action',
#  '#Adventure',
#  '#Animated',
#  '#Avant-garde',
#  '#Comedy',
#  '#Crime',
#  '#Erotic',
#  '#Fantasy',
#  '#LGBT',
#  '#Horror',
#  '#Science_fiction',
#  '#Thriller',
#  '#Western',
#  '#By_availability',
#  '#By_copyright_status',
#  '#By_technology',
#  '#By_source',
#  '#General',
#  '#Based_on_a_special_day',
#  '#Based_on_cartoons,_comics,_toys,_or_video_games',
#  '#Based_on_literature',
#  '#Based_on_religion',
#  '#Based_on_myths_and_legends',
#  '#Based_on_music_or_stage',
#  '#Based_on_television_or_radio',
#  '#By_depictions_of_historical_events_or_people',
#  '#Events',
#  '#People',
#  '#By_topic',
#  '#Social_issues',
# ...
